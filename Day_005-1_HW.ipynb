# %% [markdown]
# # [作業目標]
# - 利用範例的創建方式, 創建一組資料, 並練習如何取出最大值

# %% [markdown]
# # [作業重點]
# - 練習創立 DataFrame (In[2])
# - 如何取出口數最多的國家 (In[3], Out[3])

# %% [markdown]
# ## 練習時間
# 在小量的資料上，我們用眼睛就可以看得出來程式碼是否有跑出我們理想中的結果
#
# 請嘗試想像一個你需要的資料結構 (裡面的值可以是隨機的)，然後用上述的方法把它變成 pandas DataFrame
#
# #### Ex: 想像一個 dataframe 有兩個欄位，一個是國家，一個是人口，求人口數最多的國家
#
# ### Hints: [隨機產生數值](https://blog.csdn.net/christianashannon/article/details/78867204)

# %%
import os
import pandas as pd
import numpy as np

# %%
file = os.path.join(dir_data, '')

# %%
data = {'國家': ['Taiwan', 'United States', 'Thailand'],
        '人口': [3000000 , 50000000, 700000000]}

data1 = pd.DataFrame(data)
data1
# Out:
#               國家         人口
# 0         Taiwan    3000000
# 1  United States   50000000
# 2       Thailand  700000000

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   國家      3 non-null      object
#  1   人口      3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
# 找人口最多國家-方法1
country = data1[data1["人口"]>50000000]
print(country)
# Out:
#          國家         人口
# 2  Thailand  700000000

# %%
# 找人口最多國家-方法2
data2 = data1.sort_values(by='人口').tail(1)
data2
# Out:
#          國家         人口
# 2  Thailand  700000000
